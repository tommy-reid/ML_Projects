# %% [markdown]
# ## import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## load data and get info

# %%
Text here

# %%
cars_data = pd.read_csv('archive/cardata.csv')

# %%
cars_data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
cars_data.shape
# Out:
# (301, 9)

# %%
cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
cars_data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
cars_data.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
cars_data.duplicated().sum()
# Out:
# np.int64(2)

# %%
cars_data.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %% [markdown]
# ## Preprocessing

# %%
cars_data['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
cars_data['Seller_Type'].value_counts()
# Out:
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %%
cars_data['Transmission'].value_counts()
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# Create a sample dataframe with categorical data
Fuel = pd.DataFrame({'Fuel_Type': ['Petrol', 'Diesel', 'CNG']})
Seller = pd.DataFrame({'Seller_Type': ['Dealer', 'Individual']})
Transmiss = pd.DataFrame({'Transmission': ['Manual', 'Automatic']})

print(f"Before Encoding the Data:\n\n{Fuel}\n")
print(f"Before Encoding the Data:\n\n{Seller}\n")
print(f"Before Encoding the Data:\n\n{Transmiss}\n")
# Out:
# Before Encoding the Data:
#
#   Fuel_Type
# 0    Petrol
# 1    Diesel
# 2       CNG
#
# Before Encoding the Data:
#
#   Seller_Type
# 0      Dealer
# 1  Individual
#
# Before Encoding the Data:
#
#   Transmission
# 0       Manual
# 1    Automatic

# %%
# Create a LabelEncoder object
le = LabelEncoder()

# Fit and transform the categorical data
cars_data['Fuel_Type'] = le.fit_transform(cars_data['Fuel_Type'])
cars_data['Seller_Type'] = le.fit_transform(cars_data['Seller_Type'])
cars_data['Transmission'] = le.fit_transform(cars_data['Transmission'])

# %%
Fuel
# Out:
#   Fuel_Type
# 0    Petrol
# 1    Diesel
# 2       CNG

# %%
Seller
# Out:
#   Seller_Type
# 0      Dealer
# 1  Individual

# %%
Transmiss
# Out:
#   Transmission
# 0       Manual
# 1    Automatic

# %%
cars_data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          2
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          2
# 3  wagon r  2011           2.85           4.15        5200          2
# 4    swift  2014           4.60           6.87       42450          1
#
#    Seller_Type  Transmission  Owner
# 0            0             1      0
# 1            0             1      0
# 2            0             1      0
# 3            0             1      0
# 4            0             1      0

# %% [markdown]
# ## Build Model

# %%
x=cars_data.drop(['Car_Name','Selling_Price'],axis=1)
y=cars_data['Selling_Price']

# %%
x
# Out:
#      Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 0    2014           5.59       27000          2            0             1
# 1    2013           9.54       43000          1            0             1
# 2    2017           9.85        6900          2            0             1
# 3    2011           4.15        5200          2            0             1
# 4    2014           6.87       42450          1            0             1
# ..    ...            ...         ...        ...          ...           ...
# 296  2016          11.60       33988          1            0             1
# 297  2015           5.90       60000          2            0             1
# 298  2009          11.00       87934          2            0             1
# 299  2017          12.50        9000          1            0             1
# 300  2016           5.90        5464          2            0             1
#
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 296      0
# 297      0
# 298      0
# 299      0
# 300      0
#
# [301 rows x 7 columns]

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=11)

# %%
x_train
# Out:
#      Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 159  2017          0.510        4000          2            1             0
# 44   2012          2.690       50000          2            0             1
# 254  2013          9.900       54242          2            0             1
# 97   2017         18.640        8700          2            0             1
# 123  2013          1.470       46500          2            1             1
# ..    ...            ...         ...        ...          ...           ...
# 161  2014          0.826       23000          2            1             1
# 269  2015         10.000       18828          2            0             1
# 91   2014         16.090       58242          1            0             1
# 80   2016         14.890       23000          1            0             1
# 191  2012          0.570       25000          2            1             1
#
#      Owner
# 159      0
# 44       0
# 254      0
# 97       0
# 123      0
# ..     ...
# 161      0
# 269      0
# 91       0
# 80       0
# 191      1
#
# [240 rows x 7 columns]

# %%
x_test
# Out:
#      Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 150  2011          0.826        6000          2            1             1
# 12   2015          9.940       15000          2            0             0
# 294  2014          6.800       33019          2            0             1
# 295  2015         13.090       60076          1            0             1
# 60   2013         18.610       40001          2            0             1
# ..    ...            ...         ...        ...          ...           ...
# 212  2016         13.600       22671          2            0             1
# 262  2015          5.800       40023          2            0             1
# 70   2014          6.760       71000          1            0             1
# 202  2015          5.700       28200          2            0             1
# 170  2012          0.830        5500          2            1             1
#
#      Owner
# 150      0
# 12       0
# 294      0
# 295      0
# 60       0
# ..     ...
# 212      0
# 262      0
# 70       0
# 202      0
# 170      0
#
# [61 rows x 7 columns]

# %%
y_train
# Out:
# 159     0.45
# 44      1.25
# 254     5.25
# 97     17.00
# 123     1.00
#        ...
# 161     0.45
# 269     6.70
# 91     11.25
# 80     14.73
# 191     0.20
# Name: Selling_Price, Length: 240, dtype: float64

# %%
y_test
# Out:
# 150     0.50
# 12      7.50
# 294     3.75
# 295     8.55
# 60      6.95
#        ...
# 212    11.25
# 262     4.00
# 70      3.95
# 202     4.40
# 170     0.40
# Name: Selling_Price, Length: 61, dtype: float64

# %% [markdown]
# ## LinearRegression Model

# %%
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
training_prediction= reg.predict(x_train)

# %%
error_score=metrics.r2_score(y_train,training_prediction)

# %%
error_score
# Out:
# 0.8692300073120465

# %%
plt.scatter(y_train, training_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title(" Actual Prices vs Predicted Prices")
plt.show()

# %%
test_prediction= reg.predict(x_test)

# %%
error_score=metrics.r2_score(y_test,test_prediction)

# %%
error_score
# Out:
# 0.8294526904506089

# %%
plt.scatter(y_test, test_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title(" Actual Prices vs Predicted Prices")
plt.show()

# %% [markdown]
# ## Lasso Regression

# %%
lass_model= Lasso()

# %%
lass_model.fit(x_train,y_train)
# Out:
# Lasso()

# %%
lass_model.predict(x_train)
# Out:
# array([ 1.87280613,  1.20363704,  5.72503955, 12.48149579,  0.83418194,
#         5.8210273 ,  8.75872777,  6.65529688,  2.07837735,  7.3422437 ,
#         1.16958341,  3.35226168, 10.38431953,  5.69545033,  3.30226943,
#        18.63215953,  4.82197824,  5.29315685,  2.53387011,  0.52079812,
#         5.06764574, 10.98956728, -0.24826011,  1.34375228,  3.77085392,
#         4.93780361,  5.88007487,  1.84105454,  0.93602754,  3.4136041 ,
#         8.4343307 ,  7.59788677,  4.12305651,  6.71737915,  2.48195944,
#         3.97400344,  2.61842482,  1.69376959,  1.17416977,  1.89317525,
#         1.43674574,  6.14452147,  1.49457388,  6.12427853, 21.72034279,
#         1.58771898,  1.3594871 , 15.1119713 ,  6.77859987,  8.78301983,
#         5.27645184,  8.87443043,  1.92480066,  1.37219489,  3.72055381,
#        10.90841483, -0.42262385,  2.03135378, 10.93976538,  2.02801468,
#        -2.17637494,  5.24870458,  8.57846005, -1.03589715,  4.35548689,
#         5.02903282,  9.86838481,  4.51865369, 21.44520339,  6.6255483 ,
#         5.38623172, -0.15168503,  2.70603294,  3.71190994,  1.97990301,
#         3.12434441,  5.50121163,  4.92518606,  0.43613971,  1.8705429 ,
